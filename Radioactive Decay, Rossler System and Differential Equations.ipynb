# %% [markdown]
# # Radioactive Decay, Rossler System and Differential Equations
#
# Radioactive decay and its uses
#
# Radioactive decay is important to our health and many other things like mathematics and chemistry. We use radioactive decay to study living organisms, to diagnose and treat diseases, to sterilize medical equipment and food, to produce energy for heat and electric power, and to monitor various steps in all types of industrial activities.  Radioactive decay is used In the health industry, one way, is to help with food. We use radioactive emissions to expose food to the radiation to clean the food that we give patients so they can reduce the assumption of diseases from contamination from our food.   Radioisotopes have been used extensively in diagnosis and therapy. Radioactive isotopes are very good because they can be used as tracers and certain procedures. Since radioactive isotopes are identical chemically with stable isotopes of similar elements, they can take the place of those elements in certain medical processes. Not only that but because of their radioactivity they are very easy to trace.  Although many radioisotopes are used in tracing processes the most important seem to be iodine-131 phosphorus-32, and technetium-99m. Physicians use iodine-131 to determine things like cardiac output, plasma volume, and fat metabolism also to measure the activity of the thyroid gland where the isotope accumulates. Phosphorus-32 is useful in the identification of tumors because cancerous cells tend to accumulate phosphates more than normal cells do, which seems pretty intriguing. Technetium-99m, used along with radiographic scanning devices, is valuable for studying the anatomic structure of organs. There are also radioisotopes as cobalt-60 and cesium-137 that are widely used to treat cancer. They can be used selectively on tumors and minimize damage to adjacent healthy tissue.
#
# Applications of radioisotopes In industry are numerous. Many types of thickness gauges exploit the idea that gamma rays are weakened when they pass through material. By measuring the number of gamma rays, the thickness can be determined. This process is used in the automobile industry to test steel quality in manufacturing cars and to obtain the proper thickness of tin and aluminum. It is also used in aircraft industry to check for flaws in jet engines. In construction it is used to gauge the density of road surfaces and sub surfaces. In pipeline companies it is used to test the strength of welds. Oil, gas and mining companies use it to map the contours of test wells and mine bores and so on, the uses to radioisotopes in industry are also fairly endless.
#
# Radiometric dating is used in earth science to determine the age of rocks, Particular radioisotopes in geological material decays at a constant known rate to daughter isotopes. Using these techniques scientists have been able to determine the age of various rocks and rock formations. A special application, carbon-14 dating, have been useful to physical anthropologists and archaeologists. It helps them better organize the sequence of past events by enabling them to date more accurately fossils and artifacts from 500 to 50,000 years old.

# %% [markdown]
# ## Radioactive Decay
#
# How Radioactive decay happens
#
# A nucleus is known as the core of an atom, made up of protons and neutrons, together those two particles take up the majority of the atoms mass, the main portion of the weight is in the core, the stability of this core is how isotopes and radioactive decay begin to formulate in an atom. In the atoms process of seeking stability, it will begin to decay emitting particles known as alpha, beta, positrons and gammas, which determine the type of radiation.
# There are multiple ways that a nucleus can decay. Let’s assume we have an atom composed of 8 protons and 9 neutrons. If we decide to emit two neutrons and protons from this nucleus, and this process is known as alpha decay, the emission of an alpha particles consists of removing neutrons and protons from the nucleus of the atom. When protons are removed, or decreased in numbers from the atom the element will change. Alpha decay is known as the process of a nucleus spitting out 2 neutrons and 2 protons in order to "slim down", apparently atoms dont like themselves very much and will do what they can to become stable. The emission of these 2 particles is what is known as alpha decay.
#
#
# ![crit](https://upload.wikimedia.org/wikipedia/commons/1/1d/Descomposicion_alfa_del_uranio.gif)(Image by Jcymc90)
#
#
#
# In our example the emission of two neutron and protons is known as a helium ion with a plus charge of 2, this is known as alpha decay, due to the lack of electrons.
# If we take the same nucleus but now we focus on neutrons and the neutrons have a desire to become protons, hypothetically, they do this by emitting the electron particle, and this is known as beta decay, and a beta particle is just an emitted electron particle, since we are increasing the number of protons we are creating another element.  Now in the case of a proton wanting to become a neutron it will emit something called a positron which is the polar opposite of an electron, mass basically 0amu and charge plus 1amu and in this process called positron emission, this proton will become a neutron, and the atom will again change into a different element.
# Gamma radiation is the emission of energy in the nucleus when the particles inside the nucleus rearrange themselves, the process of radioactive decay happens entirely at random, there is no way of telling which atoms will decay and which wont. When we continue to emit these particles we keep getting different elements, this is known as a decay chain(image by Tosaka)
#
# ![crit](https://upload.wikimedia.org/wikipedia/commons/6/65/Decay_chain%284n%2B2%2C_Uranium_series%29.svg)
#
#
#
# Now all of these these processes are happening at a certain rate, but they are all different and not to mention all independent. Since decay is statistical and each decay is independent of each other, the bulk decay rate can be derived and it takes the form
#
# $$\frac{dN}{dt} = -\lambda N$$
#
# Where N is the population at a given time and lambda is the decay constant. The decay constant sets tine scales for the decay, basically the size of the decay will determine how fast or slow the decay will occure, if the decay is high then our population will decay at a very fastr rate, if our decay is slow our population will decay slowly. The uses for these two methods is very necessary. We can use fast decaying systems for patients with illnesses, what scientists do is they insert radioactive systems in patients and see results, and since they decay fast their is less risk of prolonged damage to the patients, just like the tracing we discussed earlier. The other form is used for stuff like determing the age of rocks, which we want to be as detailed as possible and since rocks arent humans we use the smallest decaying systems for this. I we wanted to figure out how much time it would take to decay a certain amount of atoms we would have to use a bit of math to do figure this out, we have to integrate our formula up above like so.
#
# $$\frac{dN}{N} = -\lambda dt$$
#
# $$\int\frac{dN}{N} = -\lambda \int dt$$
#
# $$ ln(N) - ln(N_0) = -\lambda t$$
#
# $$ ln(\frac{N}{N_0}) = -\lambda t$$
#
# $$\frac{N}{N_0} = e^{-\lambda t}$$
#
# $$N = N_0e^{-\lambda t}$$
#
#
# Now we can input values into our equation and see what we get. The concept of half life is very well known and is directly related to our radioactive decay function. Half life is defined as, the amount of time it takes for a population to be half its original size, this is simple enough, the only difficult part really is determing what our $\lamba$ would be and what relationship it holds with our equation above, and to do that we need to use some values, now we will substitute t for the half life variable, we will use 50 for $N$ and 100 for $N_0$.
#
# $$ 50 = 100e^{-\lambda \tau_{\frac{1}{2}}}$$
#
# $$ \frac{50}{100} = e^{-\lambda \tau_{\frac{1}{2}}}$$
#
# $$\frac{100}{50} = e^{\lambda \tau_{\frac{1}{2}}}$$
#
# $$ln(2) = \lambda \tau_{\frac{1}{2}}$$
#
# $$ \lambda = \frac{ln(2)}{\tau_\frac{1}{2}}$$
#
# $$\tau_\frac{1}{2} = \frac{ln(2)}{\lambda}$$
#
# And finally this is our $\lambda$ vs. $t$ relationship, and graphically this looks something like this,
#
#
# ![crit](https://whatisnuclear.com/img/half-life.png)
#
# This graph by, Nick Touran shows the example we just did for half life with our numercial values.
#
#
# It's also often useful to understand the population of a decay product of a radioactive decay, or a daughter nuclide. This may be useful for radiogenic dating and understanding nuclear waste behaviors, and so forth. If we let $t = 0$ be $D_0$ and solve, we get.
#
# $$D = D_0 + N_0 - N$$
#
# $$D = D_0 +N_0 - N_0e^{-\lambda t}$$
#
# $$D = D_0 + N_0(1 - e^{-\lambda t})$$
#
# We can show this graphically with an example of Uranium-238 and Lead-206.
#
# ![crit](https://whatisnuclear.com/img/half-life-lead-uranium.png)
#
# This graph by, Nick Touran shows how the decay of Uranium-238 eventually leads to that of Lead-206
#
# ### Euler method
#
#
# Lets assume that in a differential equation $\frac{dy}{dx} = y$ and we are given the initial condition that $y(0) = 1$ we can make a chart to describe how we would approxiate values using our given equations above, where $\frac{dy}{dx}$ is our slope and X and Y are our values we get.
#
#
# |$X$      |$Y$        |$\frac{dy}{dx}$|
# |:--------|:-----------|:-------------|
# |    $0$  |  $1$       |   $1$        |
# |    $1$  |  $2$       |   $2$        |
# |    $2$  |  $4$       |   $4$        |
# |   $3$   |  $8$       |   $8$        |
#
#
# Now it is known that $y(x) = e^x$ which is approximately $2.718$ if we make our $x$ values smaller and smaller we get closer and closwer to $2.718$ lets see an example where $x$ increases by a facotr of $0.5$
#
#
# |$X$      |$Y$        |$\frac{dy}{dx}$|
# |:--------|:-----------|:-------------|
# |    $0$  |  $1$       |   $1$        |
# |    $0.5$|  $1.5$     |   $1.5$      |
# |    $1$  |  $2.25$    |   $2.25$     |
#
#
# So you can see that the smaller we make our incriments the closer we get to our value of $e^x$ and this is what eulors method is. Lets show how this method would look graphically to see a visual example of this.
#
# ![crit](https://upload.wikimedia.org/wikipedia/commons/7/7b/Forward_Euler.jpg)
#
#
# (Gong Cheng, etc)This graph Shows how the approxiation looks for $e^x$ and if we focus our attention on the green line approximation we see that rough looking curve being formed and we can see it kind of hugging our main line that we want to approximate, this is how we use Eulers method, we also see that if we decrease out h we get a more detailed line that gets closer and closer to the real thing.
#
# Eulers method is a numerical tool for approximating values for solutions of differential equations. The eulor method is simple approach to solving differential equations that is easy to derive, lets take this for an example,
#
# $$y'(t) = f(t, y(t)), \hspace{0.5cm} y(t=0) = y_0$$
#
# Where $y'$ is the first derivative with respect to time, $y''$ is the second derivative with respect to time and so on. we can then turn this into another form of the equation if we know our values of $t_n$ and $t_{n+1}$, the derivative can be written as
#
# $$y'_n = \frac{y_{n+1} - y_n}{t_{n+1} - t_n}.$$
#
# We can then write down the difference equation as
#
# $$\frac{y_{n+1} - y_n}{t_{n+1} - t_n} = f(t_n, y_n).$$
#
# and finally the simplest form of this is
#
# $$y_{n+1} = y_n + hf(t_n, y_n).$$
#
# This equation lets us sort of look forward in time when we generalize the equation to
#
# $$y^{(N)}(t) = f(t, y(t), y^{(1)}(t), ... y^{(N-1)}(t).$$
#
# The way to go about this is to convert this into a system of equations like so.
#
# $$z_1(t) = y(t), z_2(t) = y^{(1)}(t), z_3(t) = y^{(2)}(t), ..., z_N(t) = y^{(N-1)}(t).$$
#
# We now have a system of equations. If we consider the $z_i(t)$ to be a vector, we can write down
#
# $$\textbf{z} = \begin{pmatrix}
# z_1(t) \\
# z_2(t) \\
# z_3(t) \\
# .      \\
# .      \\
# .      \\
# z_N(t)
# \end{pmatrix}.$$
#
# The system of equations then becomes,
#
# $$\textbf{z'}(t) = \begin{pmatrix}
# z_2(t) \\
# z_3(t) \\
# z_4(t) \\
# .      \\
# .      \\
# .      \\
# f(t, z_1(t), ..., z_N(t)
# \end{pmatrix}.$$
#
# This is a more in depth version of what we want to show but it is very important to visualize how we approach this concept while we implement our code, which is as follows.
#
# https://en.wikipedia.org/wiki/Radioactive_decay
# https://upload.wikimedia.org/wikipedia/commons/7/7b/Forward_Euler.jpg
# https://whatisnuclear.com/img/half-life-lead-uranium.png
# https://whatisnuclear.com/img/half-life.png
# https://upload.wikimedia.org/wikipedia/commons/1/1d/Descomposicion_alfa_del_uranio.gif
# https://upload.wikimedia.org/wikipedia/commons/6/65/Decay_chain%284n%2B2%2C_Uranium_series%29.svg

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def radioactive(N=0.1, lamb = 0.1):
    """
    Function returns the output -lamb*N. 
    
    Keywords:
    x: Input. This is the population of the species. Can be concentration too so it is ok to input floats.
    lamb: Input. This is the decay constant. Note that lambda in python has a special meaning. So we name
          this variable lamb.
    output: returns -lamb*N.
    
    """
    
    return -lamb*N

# %%
def euler(func, h=0.1, yCurrent=0.1, *funcArgs):
    """
    Function performs one Euler step returns the value for the next iteration.
    
    Keywords:
    func: right hand side of the differential equation. 
          Default is the radioactivity function i.e. radioactive().

    h: Input. This is the time step used to the advance the solution to the next time point.
    yCurrent: Value of variable at current time step.
    *funcArgs: Parameters for the function in the differential equation.
    yNext: Output. Value of the variable at the next time step.
    
    """
    
    # Initialize
    yNext = 0.0
    
    # Calculate next time step
    yNext = h*func(yCurrent, *funcArgs) + yCurrent
    
    return yNext

# %% [markdown]
# Now we want to use our new found eulor method to calculate values and see if we get something we can qualify as viable.

# %%
numIter = 10
y = np.zeros((numIter,1))
y[0] = 50.0
h = 0.5
lamb = 1.0
tList = np.linspace(0, h*numIter, numIter)

for i in range(1, len(y)):
    y[i] = euler(radioactive, h, y[i-1], lamb)

# %%
fig, axes = plt.subplots(figsize=(12, 5))

axes.plot(tList, y,  '.', markersize=12)
axes.set_xlabel('time', fontsize=15)
axes.set_ylabel('y', fontsize=15)
axes.grid(True)

# %%
numIter = 50
y = np.zeros((numIter,1))
y[0] = 50.0
h = 0.5
lamb = 1.0
tList = np.linspace(0, h*numIter, numIter)

for i in range(1, len(y)):
    y[i] = euler(radioactive, h, y[i-1], lamb)

# %%
fig, axes = plt.subplots(figsize=(12, 5))

axes.plot(tList, y,  '.', markersize=12)
axes.set_xlabel('time', fontsize=15)
axes.set_ylabel('y', fontsize=15)
axes.grid(True)

# %% [markdown]
# What are we looking at exactly here? Well the two graph representations are meant to show you the process of eulors method being applied garphically their destination is the value of 50 on the y axis vs time. I used two examples to show the differece in view one with only 10 iterations and one with 50 iterations to show the difference in the smoothness, which is a sign of a better result.  Now if we really want to see what this graph looks like compared to the exact solution we can plot the exact solution and compare it to this graph and see how close this graph is.

# %%
fig, axes = plt.subplots(figsize=(12, 5))

axes.plot(tList, y,  '.', markersize=12, label='Numerical solution using Euler method')
axes.plot(tList, y[0]*np.exp(-lamb*tList), '-', label='Exact solution')
axes.set_xlabel('time', fontsize=15)
axes.set_ylabel('y', fontsize=15)
axes.grid(True)
plt.legend(fontsize=15)
plt.xlim(0,10)
# Out:
# (0, 10)

# %% [markdown]
# We can see that this euler method is very close to the exact solution as time gets smaller the line and the points diverge a bit so it is accurate but not entirely accurate. We can see the euler line hugging the exact solution line which is what we expect to see from this solution,something almost exact but not quite there, we can see that half life happens in our graph at around t = 1 and we can see in our euler approximation its not exactly at t = 1, but a bit below 1.
#
# What were to happen if we changed our h in our above function? well we denote that in our function and h is our step size in our equation, its what we add on in the next iteration, if we were to change it it would change how the graph looks depending on how high or how low you go. Ideally you want to go aas low as possible, this will make our graph more detailed, there will be more points, but it will make the code run a bit slower because there are more calculations that have to be done but it will make it more accurate, so we see a closer correspondence to the exact solution when we make our h smaller. When we change our lambda our graph doesnt exhibit half life anymore, which suggests 1.0 is the best place to keep our lambda.
#
# ### Runge-Kutta Method
#
# The Runge-Kutta methods are a family of explicit and implicit iteritive methods that are used for approximations of Ordinary Differential Equations, one being in conjunction with the euler method.  These methods where developed around the 1900 by german mathematicians Carl Runge and Martin Kutta. The RK4 method is the most widely used method and has an initial value problem of
#
# $$ y' = f(t,y)$$
#
# and
# $$y(t_0) = y_0$$
#
# Where y is an unkown factor of time t, which is what we are trying to approximate. We define our method as follows
#
#
# $$y_{n+1} = y_n + \frac{h}{6}(k_1 + 2k_2 + 2k_3 + k_4),$$
#
# where,
#
# $$k_1 = f(t_n, y_n),$$
#
# $$k_2 = f(t_n + \frac{h}{2}, y_n + \frac{hk_1}{2}),$$
#
# $$k_3 = f(t_n + \frac{h}{2}, y_n + \frac{hk_2}{2}),$$ and
#
# $$k_4 = f(t_n + \frac{h}{2}, y_n + hk_3).$$
#
#
# here $y_{n+1}$ is the RK4 approximation of $y(t_{n+1})$ and the next value of $y_{n+1}$ is determined by the value of $y_{n}$ and we then add the weighted average of the four increments
#
# * $k_1$ is based on the slope of the first point of y(Euler Method)
# * $k_2$ is the increment based on the slope at the midpoint of the interval, y and k1
# * $k_3$ is the same as above, except now we are using y and k2 instead of k1
# * $k_4$ is the increment based on the last point using y and k3
#
# After we average the four weights, greater weight is given to the points in the midterm. The RK4 method is a fourth order differential equation which means it has a truncation error of $O(h^5)$ while the total accumulated error is $O(h^4)$, this means our error is fairly small, espeically compared to the euler method.
#
# The Explicit Runge-Kutta method is used for a wider varitey of weights and it follows as
#
# $$y_{n+1} = y_n + h\sum{b_ik_i}$$
#
# Where $i$ goes from $1$ to $s$.  Here
#
# * $k_1 = f(t_n,y_n)$
# * $k_2 = f(t_n + c_2h, y_n + h(a_{21}k_1))$
# * $k_3 = f(t_n+c_3h, y_n + h(a_{31}k_1 + a_{32}k_2))$
#
# $\bullet$
# $\bullet$
# $\bullet$
#
# * $k_s = f(t_n + c_sh, y_n +h(a_{s1}k_1+...+a_{s,s-1}k_{s-1})$
# These data are usually used as a mnenonic device known as a butcher tableau(After John C. Butcher)
#
# ![crit](https://upload.wikimedia.org/wikipedia/commons/7/7e/Runge-Kutta_slopes.svg)
#
# This a graphical representation of the RK4 fourth order ODE method(image by HilberTraum https://upload.wikimedia.org/wikipedia/commons/7/7e/Runge-Kutta_slopes.svg)
#
# In the image we see the line and the four approximations that are known as our weights, after we find our weights what we do is we find our average weight by adding them up and dividing by 4. As you cn see the slopes we find for k1, ..., k4 are somehwat hugging the graph, but differently than euler. In euler we kind of venture a bit below the graph and keep approximating along that one line, but here we get four different slopes around our graph, some above some below one straight throught the middle and then we average them all together to get our approximation.
#
# Lets make a numerical example before we get into the code so we can see this formula implemeneted and how the process looks by hand.
#
# $$\frac{dy}{dx} = x^2y$$
#
# $$y(0) = 1$$
#
# $$\triangle{x} = 0.1$$
#
# $$k_1 = f(t_n,y_n) = 0^2 * 1 = 0$$
#
# $$k_2 = f(t_n + \frac{\triangle{x}}{2}, y_n + \frac{k}{2})$$
#
# $$k_2 = (0 + \frac{1}{2}*(0.1))^2 * (1 + \frac{1}{2}(0)(0.1)) = 0.0025$$
#
# $$k_3 = f(x + \frac{\triangle{x}}{2}, y_n + \frac{k_2*\triangle{x}}{2})$$
#
# $$k_3 = ((0 + \frac{(0.1)^2}{2})*(1+\frac{(0.0025)(0.1)}{2})) = 0.0025$$
#
# $$k_4 = f(x + \triangle{x}, y_n + k_3 * \triangle{x})$$
#
# $$k_4 = (0 + (0.1)^2) * (1 + 0.0025*0.1) = 0.01000$$
#
# Now we want to pt everything together using our formula which will be something like,
#
# $$y_{i+1} = y_i + \frac{\triangle}{6}(k_1 + 2k_2 + 2k_3 + k_4)$$
#
# $$y(0.1) = 1 + \frac{0.1}{6}(0 + 2(0.0025) + 2(0.0025) + 0.001) = 1.00333$$
#
# So basically what we are saying is thay when x is 0.1 y is 1.00333.
#
# Now what we want to do is find the value of y whe x is 0.2, we could do 0.3, 0.4 and so forth...Lets see how close to 1 we can really get, we will only be doing one more example since they are a bit ardurous and lengthy but it should be more than enough to prove our point.
#
#
# $$k_1 = f(t_n,y_n) = (0.1)^2 * 1 = 0.0100$$
#
# $$k_2 = f(t_n + \frac{\triangle{x}}{2}, y_n + \frac{k}{2})$$
#
# $$k_2 = (0.1 + \frac{1}{2}*(0.1))^2 * (1.000333 + \frac{1}{2}(0.01)(0.1)) = 0.02252$$
#
# $$k_3 = f(x + \frac{\triangle{x}}{2}, y_n + \frac{k_2*\triangle{x}}{2})$$
#
# $$k_3 = ((0.1 + \frac{(0.1)^2}{2})*(1.00333+\frac{(0.02252)(0.1)}{2})) = 0.02253$$
#
# $$k_4 = f(x + \triangle{x}, y_n + k_3 * \triangle{x})$$
#
# $$k_4 = (0.1 + (0.1)^2) * (1.000333 + 0.02253*0.1) = 0.0401$$
#
# $$y_{i+1} = y_i + \frac{\triangle}{6}(k_1 + 2k_2 + 2k_3 + k_4)$$
#
# $$y(0.2) = 1.000333 + \frac{0.1}{6}(0 + 2(0.02252) + 2(0.02253) + 0.0401) = 1.002670$$
#
# So this right here is our value of y when x is 0.2 ad we can see its much closer to 1, which is the answer we are looking for, if we were to keep on going we would keep getting answers closer and closer to 1, and this is the Runge-Kutta Method. Now we should expect to see a solution very close to our exact line graph when we graph our RK4 method, lets see how it looks.

# %%
def rk4(func, h=0.1, yCurrent=0.1, *funcArgs):
    """
    Function performs one RK4 step returns the value for the next iteration.
    
    Keywords:
    func: right hand side of the differential equation. 
          Default is the radioactivity function i.e. radioactive().
    h: Input. This is the time step used to the advance the solution to the next time point.
    yCurrent: Value of variable at current time step.
    *funcArgs: Parameters for the function in the differential equation.
        
    yNext: Output. Value of the variable at the next time step.
    
    """
    
    # Initialize
    yNext = 0.0
    
    # Calculate k1, k2, k3 and k4
    
    k1 = func(yCurrent, *funcArgs)
    k2 = func(yCurrent + h*k1/2, *funcArgs)
    k3 = func(yCurrent + h*k2/2, *funcArgs)
    k4 = func(yCurrent + h*k3, *funcArgs)
    
    # Calculate next time step
    yNext = (h/6)*(k1 + 2*k2 + 2*k3 + k4) + yCurrent
    
    return yNext

# %%
numIter = 50
yRK4 = np.zeros((numIter,1))
yRK4[0] = 50.0
h = 0.5
lamb = 1.0
tList = np.linspace(0, h*numIter, numIter)

for i in range(1, len(yRK4)):
    yRK4[i] = rk4(radioactive, h, yRK4[i-1], lamb)

# %%
fig, axes = plt.subplots(figsize=(15, 12))

axes.plot(tList, yRK4, '.-', markersize=8)
axes.plot(tList, y[0]*np.exp(-lamb*tList), '-', label='Exact solution')
axes.set_xlabel('time', fontsize=15)
axes.set_ylabel('y', fontsize=15)
axes.grid(True)
plt.xlim(0,10)
# Out:
# (0, 10)

# %% [markdown]
# Whar we are seeing here is the comparison between our RK4 method and our exact solution we did with our euler method. You can barely tell the difference between the two lines, they are on top of each other, thats how accurate the RK4 method is. We can also see that at t = 1 we get exactly half of our population and at twice the half life we get around 12.5 which is what we should be getting so our results are within range of what we want to see in our graph. If we were play around with our h and $\lambda$ like we discussed in our euler graph we will notice our graph changing rather drastically, if we change our time step our graph gets more accurate, but for this i dont believe we need to since our RK4 is so accurate to the exact solution. If we change $\lambda$ we dont see half life occuring, which is not what we are trying to focus on so i wont show it. Both our euler and RK4 method show a fairly decent approximation to our exact soltion, so lets see what would happen if we were to compare both of our methods together, we can compare how accurate they are to the exact soltuion.

# %%
fig, axes = plt.subplots(figsize=(12, 10))

axes.plot(tList, y,  '.', markersize=12, label='Numerical solution, Euler method')
axes.plot(tList, yRK4,  '.', markersize=12, label='Numerical solution, RK4 method')
axes.plot(tList, y[0]*np.exp(-lamb*tList), '-', label='Exact solution')
axes.set_xlabel('time', fontsize=15)
axes.set_ylabel('y', fontsize=15)
axes.grid(True)
plt.legend(fontsize=15)
axes.set_yscale('log')

# %% [markdown]
# We can see that both linea re graphed then compared to the exact line value and what we see seems to be fairly close to what we assumed earlier on.  The RK4 method is much more accurate than the Euler method. But if you try to increase the value of $h$ without controlling the value of $\lambda$ you will have too much error build up and the algorithm will be unstable. You can still take the Rk4 method much further than the euler method which is a good advantage.  The euler method itself has a set of disadvantages that should be discussed.  The euler method is very easy to use but it has many errors that accumualate over time from iteration to iteration. If you use a large h then you will see that the method becomes too innacurate and we classify these as truncation errors. Our series that we ue for euler is a taylr expansion of the form
#
# $$y_{n+1} = y_n + h(ft_n, y_n).$$
#
# This first order equation is what we use to approximate our answer in every iteration, not the cleanest way to do it but it gets you a rough answer. We use this method but it does make a lot of errors and they do accumulate, the standard way of writing this is $O(h)$,e the accumulated errors in the first order of the time step h, this is known as the big O notation. The big O notation is a way to describe the limiting behavior of a function, usually done with approximation functions such as euler and RK4, in RK4 our O notation is $O(h^4)$ which is way smaller and thus more accuarte than that of euler.
# Euler's method uses the line tangent to the function at the beginning of the interval as an estimate of the slope of the function over the interval, assuming that if the step size is small, the error will be small this is where the error happens because as we keep using this the errors will begin to accumulate since we use the approximation as a basis for the next step and that slowly starts to diverge from the correct answer, this is very different from the Rk4. Eulers method essentially gets the first derivative correct while RK4 gets the first 4 correct, makes a larger difference. From the Taylor series this means that the Rk4 method will begin to get errors after the 4th derivative term will the euler will do so much sooner at the 2nd term, this makes for the RK4 to have a much smaller error than the Euler method, which is what we see in our graph up above. In our graph we see the RK4 line much closer to our Exact solution line than the euler method line and this is a great representation of how much better the RK4 method is than the Euler method. Although we could theoretically change the step size of both of our method, making our euler method much more accurate but even then it wouldnt be as accurate as our RK4 method and like we mentioned before our euler method would increase in time drastically if we made our step size smaller, so either way it still wouldnt be as accurate as our rk4.
# https://en.wikipedia.org/wiki/Big_O_notation

# %% [markdown]
# # Rossler Equations and Chaos(also Lorenz equation)
#
# Otto Eberhard Rossler is a German biochemist known for his work on chaos theory and the theoretical equations that when put together are put together to something known as the Rossler attractor. These equations are a system of differential equations. The Rossler Attractor is used to define a continuous tim dynamical system that exhibits chaotic dynamics associated with fractals. Chaos is known as disorder and we have dealt with chaos a bit before and if we recall correclty chaos and fractals have a lot to do with imaginary numbers, comlex numbers and complex planes.
#
# Real numbers are all over the place and they look something like this
#
# $$ 4, 0, 0.3, 0.1293367, e, \pi,...$$
#
# We have built a life in our world around real numbers, but what about complex numbers? What purpose do they serve in mathematics?  We first dared to explore the region of complex numbers when we dared to ask what would happen if you took a number squared and got back a negative 1? We defined this by $i$ and when we sqaure $i$ we get $-1$, this is the beginning of the venture into complex numbers, and with that we got a whole new class of numbers, for example.
#
# $$ i, -i, \pi*i, e*i,...$$
#
# And with this came a new question asked by scientists, what would happen if we combine imaginary numbers with real numbers?  We would get something called complex numbers. Complex numbers are numbers which can be written as $x + jy$ where $j = \sqrt{-i}$. Complex numbers can be thought of as natural extensions to real numbers. They also allow us to find solutions to equations that have no real number solutions. The complex number z can be plotted in the complex plain as a position vector.
#
# Now how we visualize complex numbers graphically is not as complicated as we would think, this is a graph of a complex plane:
#
#
# ![crit](https://upload.wikimedia.org/wikipedia/commons/5/50/A_plus_bi.svg)
#
# This graph by IkamusumeFan Shows how you would graph a complex number which would be imaginary on the y-axis and real on the x-axis. This graph is known as the complex plane. Complex planes are very useful for creating objects known as fractals. Fractals are created using iteration processes. Basically an iteration is when we start with a number and plug into a formula and when the formula spits out a number we then plug that same number into the same function and get a different number and we keet doing that. Fractals are used for many different things in our everyday lives. One use of fractals is cellphones. If we begin with an equalateral triangle and then make other triangles on the middle of each side of said trianlge then if we do it again we will be making a triangles on twelve sides of this figure and so forth until we reach infinity,until we get something known as a Koch Snowflake(image by German Wikipedia, original upload 27. Jul 2004 by Arbol01
#
# ![crit](https://upload.wikimedia.org/wikipedia/commons/f/f0/Flocke.PNG)
#
# If we think about the perimeter of a fractal as wires or antenae then we can begin to delve into why fractals are useful to everyday life, and one way for this is cellphones. Back in the day special shapes of antennas were used to recieve signals from specific broadbands, so whatever the shape for the TV antenna was that certain shape could only attract waves from other televesion casts, the same for cellphone, and radio. When fractal antennas were introduced they revolutionalized the way technology worked in recieving signals. Because a fractal has an infinite perimeter they eventually managed to cover the shape of every kind of broadband, which apparently is how our cellphones work today, so instead of having a specific antenna for every type of broadband the fractal one could recieve them all at once.
#
# The Rossler equations are a system of differential equations. They are a set of three coupled differential equations given by
#
# $$\frac{dx}{dt} = -y-z$$
#
# $$\frac{dy}{dt} = x +ay$$
#
# $$\frac{dz}{dt} = b + z(x-c)$$
#
# The three paramters can be adjusted that give rise to interesting kinds of behaviors. If we define the fixed points of our equations as $\frac{dx}{dt}, \frac{dy}{dt} and \frac{dz}{dt}$ and set them equal to 0 we can solve for the point $(x_0,y_0,z_0)$ like so
#
# $$x_0 = \frac{c\pm\sqrt{c^2 - 4ab}}{2}$$
#
# $$y_0 = -\frac{c\pm\sqrt{c^2 - 4ab}}{2a}$$
#
# $$z_0 = \frac{c\pm\sqrt{c^2 - 4ab}}{2a}$$
#
# Have you ever heard of the butterfly affect? Being able to predict things is always very difficult, despite what we have said when describing euler and his equation. The butterfly affect is the idea that if a butterfly flaps its wings it will cause something in the other side of the world to do something, wheather it be a hirricane or an astroid hitting the hearth, this theory is out there in the world,  and it is not entireyl accurate. This theory was first introduced by Rossler and also by Lorenz, they both made their own models as well depicting these situations. The root of the Lorenz idea wasa central concept in chaos theory, called "Sensitivity on Initial conditions."  An example we can use for this is the double pendulum. We all know about the regular pendulum. The motion can be predicted from which direction the pendulum will swing, using kanetic and potential energy and so forth. When another pendulum is added to the first pendulum the results we get is the basis for what we call chaos theory. The chaos in the double pendulum is due to the fact that the initial conditions of the pendulum leads to infinite many possiblities of results in whatever direction the pendulum can go, and this is why we call it chaotic, becuase we can start the position of the arm in the same position and we can never predict where it will go, kind of like the wheather. We can call this "Sensitivity on initial conditions" the slight change in initial conditions can change the course of the pendulum very drastically. The pendulum example brings us to our enxt point, the Dynamical System. Lets say we have a point in sapce, a 3D graph, a dynamical system changes the path this point takes based on how much time haas passed, as time passes the point moves around. Now sometimes, in rare cases, this point will stay in a certain area and keep making circles around that area, this particular instance is called an attractor.  Edward Lorenz made a set of equations to model a simplified weather system, this equation
#
# $$\frac{dy}{dt} = \sigma(y-x)$$
#
# $$\frac{dy}{dt} = x(\rho -z) - y$$
#
# $$\frac{dz}{dt} = xy - \beta z$$
#
# These equations are supposed to model the flow of fluid, including air, from a hot area to a cold area, sounds very similar to weather doesnt it. This is called convective fluid flow and it only happens with some specific types of clouds, known as roll clouds the rolls is when air is heated from above and cooled from below the cloud formations, they form a sort of tube shaped cloud. When these equations are solved using varying initial conditions we get something like this (gif by Dan Quinn)
#
# ![crit](https://upload.wikimedia.org/wikipedia/commons/1/13/A_Trajectory_Through_Phase_Space_in_a_Lorenz_Attractor.gif)
#
# The points in the middle where the circles are metting are known as attractors, this specific shape, known as the Lorenz Butterfly, has two attractors and this means we can never truly predict where the soltuion to our system of equations will be, which is why we may never truly predict the weather. if we try to measure the distance of the journey the point is taking we get something very interesting, which we have discussed before, we get chaos, in a graph. This makes perfect sense, since we cannot predict where the solution of these systems of equations will be if we were to try to graph this we will be a bifurcation diagram, as time goes on the graph or weather gets more and more unpredictable. We can only predict around 5-10 days ahead of time for the weather but then our models fail, and this is where the lorenz attractor originates from.
#
# The Rossler attractor is a simplified version of the Lorenz attractor, it only has one manifold as opposed to two, Rossler actually intnded to make his own attractor simpler than Lorenz, he most likely assumed he could make his model more predictable since the reasonw why the lorenze model is unpredictable is because we have two attractors, strange attractors. The Rossler system can actually be explained using things like Poincare Maps and Bifurcation diagrams(image by JJ Harison).
#
# ![crit](https://upload.wikimedia.org/wikipedia/commons/6/64/Forced_Duffing_equation_Poincaré_section.png)
#
# This is what is known as a first occurence map, or Poincare Map, it is used in dynamic systems. This was used to describe the orbit of the earth around the sun. The shape the earth makes when it is in Perihelion, the moment the eart is closest to the sun, is that of a recurrence map, this map is used throughout space to desrcibe other phenomena as well, like the movement of stars in far away galaxies.
# A bifurcation map is a logistic map used to show the unpredictability of certain things one being fertility rates and populations, they can be used for other things as well(image by AP at English).
#
# ![crit](https://upload.wikimedia.org/wikipedia/commons/b/b1/Logistic-burification.png)
# This image is that of a bifurcation diagram, another word for this diagram is a fork diagram because it kind of forks it progresses along the graph. Logistic maps are used mainly for reproduction models and starvation models, and they were made by Robert May.
#
#
# ![crit](https://upload.wikimedia.org/wikipedia/commons/7/7b/RosslerAttractor3D.svg)
#
# This image by Shiyu Ji is what the Rossler attractor is supposedd to look like in 3D and as you can see compared to the Lorenz attractor it is more predictable, only one manifold, it is theorized that this model can be used to predict many things, even how stars move around orbits of other stars. In our project we want to plot the 2D veriosn of this to show the chaos when we change our values of c, we will show this now.
# https://en.wikipedia.org/wiki/Otto_Rössler
# https://upload.wikimedia.org/wikipedia/commons/6/64/Forced_Duffing_equation_Poincaré_section.pnghttps://upload.wikimedia.org/wikipedia/commons/b/b1/Logistic-burification.png
# https://upload.wikimedia.org/wikipedia/commons/7/7b/RosslerAttractor3D.svg
# https://upload.wikimedia.org/wikipedia/commons/1/13/A_Trajectory_Through_Phase_Space_in_a_Lorenz_Attractor.gif
# https://upload.wikimedia.org/wikipedia/commons/5/50/A_plus_bi.svg
# https://upload.wikimedia.org/wikipedia/commons/f/f0/Flocke.PNG

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

a = 0.2
b = 0.2
c = 2.5

def Rossler(A, t):
    x, y, z = A  # unpack the state vector
    return  -y - z, x + a * y, b + z * (x - c)  # derivatives
    """
        Our function Rossler is meant to take our values for the rossler equation
       and vectorize them for later use.
       
       
    """

A0 = [1, 1, 1]
time = np.arange(0, 20, .01)

A = odeint(Rossler, A0, time)

fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax.plot(A[:,0], A[:,1])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

a = 0.2
b = 0.2
c = 5

def Rossler(A, t):
    x, y, z = A  # unpack the state vector
    return  -y - z, x + a * y, b + z * (x - c)  # derivatives
    """
        Our function Rossler is meant to take our values for the rossler equation
       and vectorize them for later use.
       
       
    """

A0 = [1, 1, 1]
time = np.arange(100, 500, .01)

A = odeint(Rossler, A0, time)

fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax.plot(A[:,0], A[:,1])
plt.show()

# %% [markdown]
# We only used two c values and i want to explain what is happening here. We see peiriod doubling and this is where the chaos begins to form but if we show this graphically we may be able to see it a bit better.  What we are supposed to be seeing here is the change in period. When c = 4 we have a regular occurance, when we increase our c respectively we will get what is known as period doubling. When enough doubling has occured we experience chaos, in the graph above we see the attractor begin to fold, after a certain number of iterations it begins to do this. When we plot our late time parameters we see the doubling increase even more, as you can see from the thickness of the graph.

# %%
from numpy import *
from scipy import *
from pylab import figure
# %matplotlib inline

def rossler_bifurc(x,y,z,h,a,b,c):
    x_n=x+h*(-y-z)
    y_n=y+h*(x+a*y)
    z_n=z+h*(b+z*(x-c))   
    return x_n,y_n,z_n


a=0.2
b=0.2
c=5.7

t_ini=0
t_fin=120
h=0.0001
timesteps=int((t_fin-t_ini)/h)
t=linspace(t_ini,t_fin,timesteps)

x=zeros(timesteps)
y=zeros(timesteps)
z=zeros(timesteps)

for k in range(x.size-1):
    [x[k+1],y[k+1],z[k+1]]=rossler_bifurc(x[k],y[k],z[k],t[k+1]-t[k],a,b,c)

# %%
fig =figure(figsize=(22, 22))
ax1 = fig.add_axes([0.1, 0.7, 0.4, 0.2])


ax1.plot(t, x,color='red',label='x(t)')
ax1.set_xlabel('t')
ax1.set_ylabel('x(t)')
ax1.legend()
ax1.axis((t_ini,t_fin,min(x),max(x)))
# Out:
# (0, 120, -9.0264169828867509, 11.359315845952956)

# %%
fig =figure(figsize=(22, 22))
ax2 = fig.add_axes([0.1, 0.4, 0.4, 0.2])

ax2.plot(t, y,color='green',lw=1,label='y(t)')
ax2.set_xlabel('t')
ax2.set_ylabel('y(t)')
ax2.legend()
ax2.axis((t_ini,t_fin,min(x),max(x)))
# Out:
# (0, 120, -9.0264169828867509, 11.359315845952956)

# %% [markdown]
# Here what we have done is plotted the time series y vs t first in red and then we plotted x vs t. What we see here is a very simple illustration of bifurcation is and this is due to the infinite amount of possibiities that come from the Rossler Attractor. Bifurcation, as we may know by now is a study of changes in structures of space or continuity of a given family, such as integral curves and also differential equations, which come hand in hand with vector fields. Bifurcation is mainly used in conjunction with dynamical systems, which is what we are doing right now. A bifurcation occurs when a small change to parameter values, in this case 'c' is our value, causes a shift in the topology of something, it could be population or even something as inconsistent as weather. Here we observe bifurcation occuring in our Rossler attractor. The reason for this ties together fairly well with chaos. Chaos is the drastic change in something with a small change in parameters, similar to bifurcation, chaos and bifurcation go hand in hand, usually where you see one you see the other. The bifurcation is occuring here, but in reality what we are seeing is period doubling. The erratic shift in the graph from period to period is what we are observing as the chaotic behavior.
#
# https://en.wikipedia.org/wiki/Attractor
# http://homepages.ulb.ac.be/~gaspard/G.Roessler.Encycl.05.pdf
# https://en.wikipedia.org/wiki/Rössler_attractor
# https://en.wikipedia.org/wiki/Bifurcation_theory
# http://detritus.fundacioace.com/pub/books/Strogatz%20-%20Nonlinear%20dynamics%20and%20chaos.pdf

# %% [markdown]
# # Conclusion
#
#
# Differential equations were very important in this project and without some knowledge on them you would not have gotten very far, We used derivatives and antidervatives in every section of this project and our graphs were plotted becuasue of these so mathematics was essential to get to this part of our project.
#
# Radioactive decay is very useful for the future on humans and can even better the world. Radioisotopes are used to study animals, in industry and even in mathematics. When you have cancer they try to locate tumors with radioisotopes. Decay makes its way into this because radioisotopes are very bad for the human body, why? These unstable atoms are releasing gamma radiation along with other types of radiation, completely at random. These emission are very strong and bad for humans so timing is probably one of the most important things that we need to worry about in these kind of situations. Radioactive decay is characterized as the amount of time it takes for an atom to decompose, die out. We use certain dyes to locate tumors and other things in the human body and when we locate those things we need those chemicals to die off fast so we look for chemicals that have very high decay rates, which means they die off fast so we can get in and out as soon as possible with minimal affects on the human body. Radioactive decay is what we use to determine how long an atom will live and we use half life to determine how long it will take for the life span to be cut in half. Half Life can be characterized as
#
# $$\tau_\frac{1}{2} = \frac{ln(2)}{\lambda}$$
#
# And in our project we fiddled with this a bit and graphed the affect half life would have on a population, we used eulers method combined with our half life formula to see would happen. We discovered that eulers method is fairly accurate in approximating the correct answer that we were loooking for. In our example we started with an initial value of about 50 and with half life it would be cut in half by the next iteration, so we knew what our answer would be in the next point of our graph. With Euler we saw that the answer was approximately a few numbers lower that where it needed to be, this was because our step size was not small enough, if we were to decreas our step size, h, then the answer would be much closer but the draw back from that is that it would take the code more time to implement so we brought in a more refined version of approximation. We used the Runge-Kutta 4 method. This method is way better, faster, and more accurate than eulers method. Basically what this new method deoes it it takes up to the fourth derivative, or slopes of the graph we want to approximate and it averages them and then we graph the end result. This method is very good for approximation, i thought euler was fine but its nothing compared to how accurate this is. When we graph our results we get a graph that is almost identical to our exact solution, which we were comparing to both graphs, so not only is this method more effective but its more accurate and not to mention much faster than eulers method.
#
#
# The next section of our project focused on Attractors and this was very interesting because we learned about Lorenz and Rossler. Lorenz was the first to do this and what he had in mind was prediction of things you cant predict. he devised three equations that looked something like this
#
# $$\frac{dy}{dt} = \sigma(y-x)$$
#
# $$\frac{dy}{dt} = x(\rho -z) - y$$
#
# $$\frac{dz}{dt} = xy - \beta z$$
#
# And with these he slowly began to formulate what would later be known as the Lorenz Attractor. Now an attractor is determined when there is a series of data that gravitate towards a certain area of the graph (image by Paul Bourke http://paulbourke.net/fractals/lorenz/lorenz11.gif)
#
# ![crit](http://paulbourke.net/fractals/lorenz/lorenz11.gif)
#
# Now you can see where the graph kind of cultivates and the density is a bit more there towards the center. Rossler wanted to do something similar to Lorenz but not as compliacted, Lorenz's model is too unpredictable. So Rossler came up with a simplified version of this and it was coined the Rossler Attractor, now its unique compared to Lorenz's model becuase it doesnt have two points of conversion it only has one point, and this most likely has many applcations, most likely less unpredictablilty so it can be used for more things. Now Rosslers model could be explained with graphs and what we saw when we fiddled with our c parameter was period doubling, now the code doesnt do it justice but this is in conjunction with bifurcation theory and chaos theory and this is fairly intruiging because it shows when chaos happens depending on the amount of periods we have, if you have too many 'rings' you can see that they are uncountable and this is usually of sign of Chaos, very similar to bifurcation of a population when their firtility is too high and we observe the seasonal changes.

# %% [markdown]
# # Cited
#
# * https://en.wikipedia.org/wiki/Big_O_notation
# * https://en.wikipedia.org/wiki/Radioactive_decay
# * https://en.wikipedia.org/wiki/Otto_Rössler
# * https://en.wikipedia.org/wiki/Attractor
# * http://homepages.ulb.ac.be/~gaspard/G.Roessler.Encycl.05.pdf
# * https://en.wikipedia.org/wiki/Rössler_attractor
# * https://en.wikipedia.org/wiki/Bifurcation_theory
# * http://detritus.fundacioace.com/pub/books/Strogatz%20-%20Nonlinear%20dynamics%20and%20chaos.pdf
